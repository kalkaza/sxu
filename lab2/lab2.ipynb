# %%
"""Lab2"""

import numpy as np
import pandas as pd

# %%
#Wczytanie pliku
df = pd.read_csv("samochody1tys.csv")

#Wyświetlenie
df
# Out:
#       id       marka        model  rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III         2014.0         Diesel
# 1      1         BMW       X1 E84         2012.0         Diesel
# 2      2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3      3     Hyundai        i10 I         2008.0        Benzyna
# 4      4  Volkswagen           CC         2010.0         Diesel
# ..   ...         ...          ...            ...            ...
# 995  995  Alfa Romeo          159         2009.0         Diesel
# 996  996       Škoda     Fabia II         2012.0        Benzyna
# 997  997     Renault        Modus         2004.0        Benzyna
# 998  998        Audi        A3 8L         2000.0        Benzyna
# 999  999       Volvo      XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0               1600.0  160000.0   75900.0    Dolnośląskie
# 1               2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %%
#Pierwsze pięć wierszy
df.head()
# Out:
#    id       marka        model  rok_produkcji rodzaj_silnika  \
# 0   0      Nissan  X-Trail III         2014.0         Diesel
# 1   1         BMW       X1 E84         2012.0         Diesel
# 2   2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3   3     Hyundai        i10 I         2008.0        Benzyna
# 4   4  Volkswagen           CC         2010.0         Diesel
#
#    pojemnosc_silnika  przebieg     cena     wojewodztwo
# 0             1600.0  160000.0  75900.0    Dolnośląskie
# 1             2000.0  149000.0  70900.0  Świętokrzyskie
# 2             1600.0   99000.0   9800.0        Opolskie
# 3             1100.0   93000.0  11900.0         Łódzkie
# 4             1968.0  127428.0  49900.0   Wielkopolskie

# %%
#Pierwsze dziesięć wierszy
df.head(10)
# Out:
#    id       marka        model  rok_produkcji rodzaj_silnika  \
# 0   0      Nissan  X-Trail III         2014.0         Diesel
# 1   1         BMW       X1 E84         2012.0         Diesel
# 2   2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3   3     Hyundai        i10 I         2008.0        Benzyna
# 4   4  Volkswagen           CC         2010.0         Diesel
# 5   5        Fiat          500         2014.0    Elektryczny
# 6   6      Nissan    X-Trail I         2004.0         Diesel
# 7   7        Seat    Toledo II         2000.0        Benzyna
# 8   8  Volkswagen           CC         2014.0         Diesel
# 9   9      Nissan         Juke         2016.0        Benzyna
#
#    pojemnosc_silnika  przebieg     cena     wojewodztwo
# 0             1600.0  160000.0  75900.0    Dolnośląskie
# 1             2000.0  149000.0  70900.0  Świętokrzyskie
# 2             1600.0   99000.0   9800.0        Opolskie
# 3             1100.0   93000.0  11900.0         Łódzkie
# ...

# %%
#Ostatnie pięć wierszy
df.tail()
# Out:
#       id       marka     model  rok_produkcji rodzaj_silnika  \
# 995  995  Alfa Romeo       159         2009.0         Diesel
# 996  996       Škoda  Fabia II         2012.0        Benzyna
# 997  997     Renault     Modus         2004.0        Benzyna
# 998  998        Audi     A3 8L         2000.0        Benzyna
# 999  999       Volvo   XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena  wojewodztwo
# 995             2387.0  182000.0   33900.0  Małopolskie
# 996             1200.0   42700.0   25400.0    Lubelskie
# 997             1200.0  168111.0   10900.0      Łódzkie
# 998             1595.0  226500.0    5400.0  Małopolskie
# 999             1969.0   13617.0  136900.0  Małopolskie

# %%
#Ostatnie dziesięć wierszy
df.tail(10)
# Out:
#       id          marka         model  rok_produkcji rodzaj_silnika  \
# 990  990  Mercedes-Benz  Klasa S W126         1986.0    Benzyna+LPG
# 991  991      Chevrolet         Cruze         2010.0        Benzyna
# 992  992        Renault       Clio IV         2017.0        Benzyna
# 993  993           Fiat       Tipo II         2017.0        Benzyna
# 994  994           Fiat      Bravo II         2007.0         Diesel
# 995  995     Alfa Romeo           159         2009.0         Diesel
# 996  996          Škoda      Fabia II         2012.0        Benzyna
# 997  997        Renault         Modus         2004.0        Benzyna
# 998  998           Audi         A3 8L         2000.0        Benzyna
# 999  999          Volvo       XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena          wojewodztwo
# 990             2600.0  336000.0   21500.0       Świętokrzyskie
# 991             1598.0    7560.0   21900.0  Warmińsko-mazurskie
# ...

# %%
#Wyświetlenie indexu
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#Szybkie generowanie statystyk
df.describe()
# Out:
#                 id  rok_produkcji  pojemnosc_silnika       przebieg  \
# count  1000.000000    1000.000000        1000.000000    1000.000000
# mean    499.500000    2009.009000        2040.065000  132556.677000
# std     288.819436       5.907946        6014.545066   90094.944138
# min       0.000000    1979.000000           1.000000       1.000000
# 25%     249.750000    2005.000000        1500.000000   51750.000000
# 50%     499.500000    2009.000000        1800.000000  149000.000000
# 75%     749.250000    2014.000000        2000.000000  193000.000000
# max     999.000000    2017.000000      191000.000000  647000.000000
#
#                 cena
# count    1000.000000
# mean    51942.181000
# std     70057.918015
# min       650.000000
# 25%     14900.000000
# 50%     27250.000000
# 75%     58900.000000
# max    616000.000000

# %%
#Transpozycja danych
df.T
# Out:
#                             0               1            2        3    \
# id                            0               1            2        3
# marka                    Nissan             BMW         Opel  Hyundai
# model               X-Trail III          X1 E84     Zafira A    i10 I
# rok_produkcji              2014            2012         2004     2008
# rodzaj_silnika           Diesel          Diesel  Benzyna+CNG  Benzyna
# pojemnosc_silnika          1600            2000         1600     1100
# przebieg                 160000          149000        99000    93000
# cena                      75900           70900         9800    11900
# wojewodztwo        Dolnośląskie  Świętokrzyskie     Opolskie  Łódzkie
#
#                              4            5             6          7    \
# id                             4            5             6          7
# marka                 Volkswagen         Fiat        Nissan       Seat
# ...

# %%
#Posortowanie kolumn nazwami w kolejności odwrotnie alfabetycznej
df.sort_index(axis=1, ascending=False)
# Out:
#         wojewodztwo  rok_produkcji rodzaj_silnika  przebieg  \
# 0      Dolnośląskie         2014.0         Diesel  160000.0
# 1    Świętokrzyskie         2012.0         Diesel  149000.0
# 2          Opolskie         2004.0    Benzyna+CNG   99000.0
# 3           Łódzkie         2008.0        Benzyna   93000.0
# 4     Wielkopolskie         2010.0         Diesel  127428.0
# ..              ...            ...            ...       ...
# 995     Małopolskie         2009.0         Diesel  182000.0
# 996       Lubelskie         2012.0        Benzyna   42700.0
# 997         Łódzkie         2004.0        Benzyna  168111.0
# 998     Małopolskie         2000.0        Benzyna  226500.0
# 999     Małopolskie         2016.0         Diesel   13617.0
#
#      pojemnosc_silnika        model       marka   id      cena
# 0               1600.0  X-Trail III      Nissan    0   75900.0
# 1               2000.0       X1 E84         BMW    1   70900.0
# ...

# %%
#Sortowanie wszystkich wartości tabeli od pojazdu z majmniejszym przebiegiem
df.sort_values(by='przebieg')
# Out:
#       id          marka             model  rok_produkcji rodzaj_silnika  \
# 92    92           Jeep           Compass         2017.0         Diesel
# 32    32         Suzuki       SX4 S-Cross         2017.0        Benzyna
# 121  121        Hyundai         Tucson II         2017.0        Benzyna
# 837  837        Renault         Scenic IV         2017.0        Benzyna
# 836  836        Renault           Clio IV         2017.0        Benzyna
# ..   ...            ...               ...            ...            ...
# 82    82  Mercedes-Benz      Klasa E W210         2000.0         Diesel
# 989  989            BMW       Seria 5 E39         2002.0         Diesel
# 971  971  Mercedes-Benz      Klasa E W211         2003.0         Diesel
# 243  243     Volkswagen          Multivan         1994.0         Diesel
# 238  238  Mercedes-Benz  W124 (1984-1993)         1991.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena         wojewodztwo
# ...

# %%
#Wyświetlanie danych z podanego zakresu
df[5:20]
# Out:
#     id          marka          model  rok_produkcji rodzaj_silnika  \
# 5    5           Fiat            500         2014.0    Elektryczny
# 6    6         Nissan      X-Trail I         2004.0         Diesel
# 7    7           Seat      Toledo II         2000.0        Benzyna
# 8    8     Volkswagen             CC         2014.0         Diesel
# 9    9         Nissan           Juke         2016.0        Benzyna
# 10  10         Toyota  Corolla Seria         2015.0        Benzyna
# 11  11            BMW    Seria 5 E39         2002.0         Diesel
# 12  12     Volkswagen       Jetta A6         2014.0        Benzyna
# 13  13           Audi             A1         2011.0        Benzyna
# 14  14            BMW    Seria 3 E90         2008.0         Diesel
# 15  15        Citroën   C4 Picasso I         2007.0         Diesel
# 16  16           Ford     Mondeo Mk3         2003.0         Diesel
# 17  17  Mercedes-Benz   Klasa E W213         2017.0         Diesel
# ...

# %%
#Wyświetlanie danych z podanego zakresu, ze skokiem co 3
df[5:20:3]
# Out:
#     id          marka         model  rok_produkcji rodzaj_silnika  \
# 5    5           Fiat           500         2014.0    Elektryczny
# 8    8     Volkswagen            CC         2014.0         Diesel
# 11  11            BMW   Seria 5 E39         2002.0         Diesel
# 14  14            BMW   Seria 3 E90         2008.0         Diesel
# 17  17  Mercedes-Benz  Klasa E W213         2017.0         Diesel
#
#     pojemnosc_silnika  przebieg      cena  wojewodztwo
# 5                 1.0   36800.0   74200.0      Śląskie
# 8              1968.0   52000.0   97000.0    Pomorskie
# 11             3000.0  254900.0   17500.0  Mazowieckie
# 14             1998.0  246000.0   27999.0    Lubelskie
# 17             1950.0       5.0  258709.0      Łódzkie

# %%
#Wyświetlanie samych marek, modeli aut,przebiegów i cen
df.loc[:, ['marka', 'model', 'przebieg', 'cena']]
# Out:
#           marka        model  przebieg      cena
# 0        Nissan  X-Trail III  160000.0   75900.0
# 1           BMW       X1 E84  149000.0   70900.0
# 2          Opel     Zafira A   99000.0    9800.0
# 3       Hyundai        i10 I   93000.0   11900.0
# 4    Volkswagen           CC  127428.0   49900.0
# ..          ...          ...       ...       ...
# 995  Alfa Romeo          159  182000.0   33900.0
# 996       Škoda     Fabia II   42700.0   25400.0
# 997     Renault        Modus  168111.0   10900.0
# 998        Audi        A3 8L  226500.0    5400.0
# 999       Volvo      XC 60 I   13617.0  136900.0
#
# [1000 rows x 4 columns]

# %%
#Skopwiowanie wartosci do innej zmiennej
copy = df.copy()

#Zamiana na numpy
copy.to_numpy()
# Out:
# array([[0, 'Nissan', 'X-Trail III', ..., 160000.0, 75900.0,
#         'Dolnośląskie'],
#        [1, 'BMW', 'X1 E84', ..., 149000.0, 70900.0, 'Świętokrzyskie'],
#        [2, 'Opel', 'Zafira A', ..., 99000.0, 9800.0, 'Opolskie'],
#        ...,
#        [997, 'Renault', 'Modus', ..., 168111.0, 10900.0, 'Łódzkie'],
#        [998, 'Audi', 'A3 8L', ..., 226500.0, 5400.0, 'Małopolskie'],
#        [999, 'Volvo', 'XC 60 I', ..., 13617.0, 136900.0, 'Małopolskie']],
#       dtype=object)

# %%
#Wyświetlenie pozycji nr 10
df.iloc[10]
# Out:
# id                              10
# marka                       Toyota
# model                Corolla Seria
# rok_produkcji                 2015
# rodzaj_silnika             Benzyna
# pojemnosc_silnika             1329
# przebieg                     26415
# cena                         53000
# wojewodztwo               Lubuskie
# Name: 10, dtype: object

# %%
#Wyświetlanie zakresu
df[10:20]
# Out:
#     id          marka          model  rok_produkcji rodzaj_silnika  \
# 10  10         Toyota  Corolla Seria         2015.0        Benzyna
# 11  11            BMW    Seria 5 E39         2002.0         Diesel
# 12  12     Volkswagen       Jetta A6         2014.0        Benzyna
# 13  13           Audi             A1         2011.0        Benzyna
# 14  14            BMW    Seria 3 E90         2008.0         Diesel
# 15  15        Citroën   C4 Picasso I         2007.0         Diesel
# 16  16           Ford     Mondeo Mk3         2003.0         Diesel
# 17  17  Mercedes-Benz   Klasa E W213         2017.0         Diesel
# 18  18     Volkswagen      Tiguan II         2017.0         Diesel
# 19  19  Mercedes-Benz        GLK GLK         2012.0         Diesel
#
#     pojemnosc_silnika  przebieg      cena         wojewodztwo
# 10             1329.0   26415.0   53000.0            Lubuskie
# 11             3000.0  254900.0   17500.0         Mazowieckie
# ...

# %%
#Wyświetlone 3 kolumny z zakresu
df.iloc[10:20, :3]
# Out:
#     id          marka          model
# 10  10         Toyota  Corolla Seria
# 11  11            BMW    Seria 5 E39
# 12  12     Volkswagen       Jetta A6
# 13  13           Audi             A1
# 14  14            BMW    Seria 3 E90
# 15  15        Citroën   C4 Picasso I
# 16  16           Ford     Mondeo Mk3
# 17  17  Mercedes-Benz   Klasa E W213
# 18  18     Volkswagen      Tiguan II
# 19  19  Mercedes-Benz        GLK GLK

# %%
#Wyświetlanie konkretnej wartości
df.iloc[3,3]
# Out:
# 2008.0

# %%
#Wyświetl pojazdy wyprodukowane po 2010
df[df.rok_produkcji > 2010]
# Out:
#       id       marka        model  rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III         2014.0         Diesel
# 1      1         BMW       X1 E84         2012.0         Diesel
# 5      5        Fiat          500         2014.0    Elektryczny
# 8      8  Volkswagen           CC         2014.0         Diesel
# 9      9      Nissan         Juke         2016.0        Benzyna
# ..   ...         ...          ...            ...            ...
# 988  988         BMW           M2         2017.0        Benzyna
# 992  992     Renault      Clio IV         2017.0        Benzyna
# 993  993        Fiat      Tipo II         2017.0        Benzyna
# 996  996       Škoda     Fabia II         2012.0        Benzyna
# 999  999       Volvo      XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0               1600.0  160000.0   75900.0    Dolnośląskie
# 1               2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %%
#Wyświetl pojazdy wyprodukowane po 2010, posortowane od najtańszego
df[df.rok_produkcji > 2010].sort_values(by='cena')
# Out:
#       id          marka                 model  rok_produkcji rodzaj_silnika  \
# 442  442            Kia               Cee'd I         2011.0         Diesel
# 977  977        Renault              Clio III         2011.0        Benzyna
# 364  364        Peugeot                   207         2011.0         Diesel
# 142  142           Opel               Agila B         2011.0        Benzyna
# 97    97          Škoda              Fabia II         2012.0         Diesel
# ..   ...            ...                   ...            ...            ...
# 410  410            BMW        Seria 7 G11/12         2017.0        Hybryda
# 517  517           Audi                   RS7         2016.0        Benzyna
# 855  855     Land Rover  Range Rover Sport II         2016.0        Benzyna
# 586  586  Mercedes-Benz          Klasa G W463         2013.0        Benzyna
# 405  405  Mercedes-Benz               SL R231         2016.0        Benzyna
#
# ...

# %%
#Wyświetlanie wartości z konkretną zmienną
df[df['rodzaj_silnika'].isin(['Benzyna'])]
# Out:
#       id       marka          model  rok_produkcji rodzaj_silnika  \
# 3      3     Hyundai          i10 I         2008.0        Benzyna
# 7      7        Seat      Toledo II         2000.0        Benzyna
# 9      9      Nissan           Juke         2016.0        Benzyna
# 10    10      Toyota  Corolla Seria         2015.0        Benzyna
# 12    12  Volkswagen       Jetta A6         2014.0        Benzyna
# ..   ...         ...            ...            ...            ...
# 992  992     Renault        Clio IV         2017.0        Benzyna
# 993  993        Fiat        Tipo II         2017.0        Benzyna
# 996  996       Škoda       Fabia II         2012.0        Benzyna
# 997  997     Renault          Modus         2004.0        Benzyna
# 998  998        Audi          A3 8L         2000.0        Benzyna
#
#      pojemnosc_silnika  przebieg     cena  wojewodztwo
# 3               1100.0   93000.0  11900.0      Łódzkie
# 7               1800.0  140700.0   8150.0    Pomorskie
# ...

# %%
#Mediana danych kolumn
df.mean()
# Out:
# id                      499.500
# rok_produkcji          2009.009
# pojemnosc_silnika      2040.065
# przebieg             132556.677
# cena                  51942.181
# dtype: float64

# %%
#Mediana danych wierszy
df.mean(1)
# Out:
# 0      47902.8
# 1      44782.6
# 2      22481.2
# 3      21602.2
# 4      36262.0
#         ...
# 995    44258.2
# 996    14461.6
# 997    36642.4
# 998    47298.6
# 999    31100.2
# Length: 1000, dtype: float64

# %%
#sumowanie kolejnych wartości funkcją cumsum
df[20:25].apply(np.cumsum)
# Out:
#      id                                  marka  \
# 20   20                                  Honda
# 21   41                     HondaMercedes-Benz
# 22   63            HondaMercedes-BenzChevrolet
# 23   86       HondaMercedes-BenzChevroletVolvo
# 24  110  HondaMercedes-BenzChevroletVolvoVolvo
#
#                                   model  rok_produkcji  \
# 20                              CR-V IV         2017.0
# 21                  CR-V IVKlasa E W213         4034.0
# 22           CR-V IVKlasa E W213Captiva         6040.0
# 23        CR-V IVKlasa E W213CaptivaV50         8051.0
# 24  CR-V IVKlasa E W213CaptivaV50S40 II        10059.0
#
#                      rodzaj_silnika  pojemnosc_silnika  przebieg      cena  \
# 20                          Benzyna             2000.0       5.0  111600.0
# 21                    BenzynaDiesel             3950.0       7.0  404400.0
# 22              BenzynaDieselDiesel             5941.0  219007.0  429399.0
# ...

# %%
#zmiana indexu i dodanie kolumny
copy = copy.reindex(index=copy[0:5], columns=list(copy.columns) + ['test'])
print(copy)
# Out:
#                                                     id marka model  \
# (0, Nissan, X-Trail III, 2014.0, Diesel, 1600.0... NaN   NaN   NaN
# (1, BMW, X1 E84, 2012.0, Diesel, 2000.0, 149000... NaN   NaN   NaN
# (2, Opel, Zafira A, 2004.0, Benzyna+CNG, 1600.0... NaN   NaN   NaN
# (3, Hyundai, i10 I, 2008.0, Benzyna, 1100.0, 93... NaN   NaN   NaN
# (4, Volkswagen, CC, 2010.0, Diesel, 1968.0, 127... NaN   NaN   NaN
#
#                                                     rok_produkcji  \
# (0, Nissan, X-Trail III, 2014.0, Diesel, 1600.0...            NaN
# (1, BMW, X1 E84, 2012.0, Diesel, 2000.0, 149000...            NaN
# (2, Opel, Zafira A, 2004.0, Benzyna+CNG, 1600.0...            NaN
# (3, Hyundai, i10 I, 2008.0, Benzyna, 1100.0, 93...            NaN
# (4, Volkswagen, CC, 2010.0, Diesel, 1968.0, 127...            NaN
#
#                                                    rodzaj_silnika  \
# (0, Nissan, X-Trail III, 2014.0, Diesel, 1600.0...            NaN
# ...

# %%
#Wyrzucenie pustych danych
copy.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [id, marka, model, rok_produkcji, rodzaj_silnika, pojemnosc_silnika, przebieg, cena, wojewodztwo, test]
# Index: []

# %%
#Sprawdzanie czy są wartości NaN
pd.isna(copy)
# Out:
#                                                       id  marka  model  \
# (0, Nissan, X-Trail III, 2014.0, Diesel, 1600.0...  True   True   True
# (1, BMW, X1 E84, 2012.0, Diesel, 2000.0, 149000...  True   True   True
# (2, Opel, Zafira A, 2004.0, Benzyna+CNG, 1600.0...  True   True   True
# (3, Hyundai, i10 I, 2008.0, Benzyna, 1100.0, 93...  True   True   True
# (4, Volkswagen, CC, 2010.0, Diesel, 1968.0, 127...  True   True   True
#
#                                                     rok_produkcji  \
# (0, Nissan, X-Trail III, 2014.0, Diesel, 1600.0...           True
# (1, BMW, X1 E84, 2012.0, Diesel, 2000.0, 149000...           True
# (2, Opel, Zafira A, 2004.0, Benzyna+CNG, 1600.0...           True
# (3, Hyundai, i10 I, 2008.0, Benzyna, 1100.0, 93...           True
# (4, Volkswagen, CC, 2010.0, Diesel, 1968.0, 127...           True
#
#                                                     rodzaj_silnika  \
# (0, Nissan, X-Trail III, 2014.0, Diesel, 1600.0...            True
# ...

# %%
#Uzupełnienie pustych komórek wybraną wartością
copy = copy.fillna(value=0)

# %%
#Sprawdzanie czy są wartości NaN
pd.isna(copy)
# Out:
#                                                        id  marka  model  \
# (0, Nissan, X-Trail III, 2014.0, Diesel, 1600.0...  False  False  False
# (1, BMW, X1 E84, 2012.0, Diesel, 2000.0, 149000...  False  False  False
# (2, Opel, Zafira A, 2004.0, Benzyna+CNG, 1600.0...  False  False  False
# (3, Hyundai, i10 I, 2008.0, Benzyna, 1100.0, 93...  False  False  False
# (4, Volkswagen, CC, 2010.0, Diesel, 1968.0, 127...  False  False  False
#
#                                                     rok_produkcji  \
# (0, Nissan, X-Trail III, 2014.0, Diesel, 1600.0...          False
# (1, BMW, X1 E84, 2012.0, Diesel, 2000.0, 149000...          False
# (2, Opel, Zafira A, 2004.0, Benzyna+CNG, 1600.0...          False
# (3, Hyundai, i10 I, 2008.0, Benzyna, 1100.0, 93...          False
# (4, Volkswagen, CC, 2010.0, Diesel, 1968.0, 127...          False
#
#                                                     rodzaj_silnika  \
# ...

# %%
#Sprawdzanie czy nie ma wartości NaN
pd.notna(copy)
# Out:
#                                                       id  marka  model  \
# (0, Nissan, X-Trail III, 2014.0, Diesel, 1600.0...  True   True   True
# (1, BMW, X1 E84, 2012.0, Diesel, 2000.0, 149000...  True   True   True
# (2, Opel, Zafira A, 2004.0, Benzyna+CNG, 1600.0...  True   True   True
# (3, Hyundai, i10 I, 2008.0, Benzyna, 1100.0, 93...  True   True   True
# (4, Volkswagen, CC, 2010.0, Diesel, 1968.0, 127...  True   True   True
#
#                                                     rok_produkcji  \
# (0, Nissan, X-Trail III, 2014.0, Diesel, 1600.0...           True
# (1, BMW, X1 E84, 2012.0, Diesel, 2000.0, 149000...           True
# (2, Opel, Zafira A, 2004.0, Benzyna+CNG, 1600.0...           True
# (3, Hyundai, i10 I, 2008.0, Benzyna, 1100.0, 93...           True
# (4, Volkswagen, CC, 2010.0, Diesel, 1968.0, 127...           True
#
#                                                     rodzaj_silnika  \
# (0, Nissan, X-Trail III, 2014.0, Diesel, 1600.0...            True
# ...

# %%
#Grupowanie po konkretnej wartości
df.groupby("rok_produkcji").sum()
# Out:
#                   id  pojemnosc_silnika    przebieg        cena
# rok_produkcji
# 1979.0           611             4903.0     99999.0     36000.0
# 1984.0           834             7800.0    431605.0     75000.0
# 1986.0          1474             5600.0    425000.0     36499.0
# 1988.0           650             2300.0    270000.0     11900.0
# 1991.0           238             1997.0    647000.0      4000.0
# 1992.0          2051             6953.0    466933.0     57499.0
# 1993.0           587             1796.0     81000.0     26500.0
# 1994.0          1367            15464.0   1169000.0     60200.0
# 1995.0          1954             5781.0    354022.0     25899.0
# 1996.0           657             1795.0    133300.0      3200.0
# 1997.0          2573             9589.0   1006523.0     31199.0
# 1998.0          3547            13021.0   1447653.0     55000.0
# 1999.0          5810            18972.0   2151947.0     60199.0
# ...

# %%
#Grupowanie po konkretnych wartościach
df.groupby(["rok_produkcji", "marka"]).sum()
# Out:
#                                 id  pojemnosc_silnika  przebieg       cena
# rok_produkcji marka
# 1979.0        Chevrolet        611             4903.0   99999.0    36000.0
# 1984.0        Mercedes-Benz    834             7800.0  431605.0    75000.0
# 1986.0        Mercedes-Benz    990             2600.0  336000.0    21500.0
#               Opel             484             3000.0   89000.0    14999.0
# 1988.0        Mercedes-Benz    650             2300.0  270000.0    11900.0
# ...                            ...                ...       ...        ...
# 2017.0        Suzuki          1426             5026.0       4.0   257780.0
#               Toyota           549             2796.0     153.0   162100.0
#               Volkswagen     10205            32968.0   23454.0  2359399.0
#               Volvo             43             1986.0       1.0   158600.0
#               Škoda           3206            10812.0    4226.0   671980.0
#
# [396 rows x 4 columns]

# %%
#Przerobienie macierzy na stack
copy = df.copy()
stacked = copy.stack()
print(stacked)
# Out:
# 0    id                             0
#      marka                     Nissan
#      model                X-Trail III
#      rok_produkcji               2014
#      rodzaj_silnika            Diesel
#                              ...
# 999  rodzaj_silnika            Diesel
#      pojemnosc_silnika           1969
#      przebieg                   13617
#      cena                      136900
#      wojewodztwo          Małopolskie
# Length: 9000, dtype: object

# %%
#Przerobienie stacka na macierz
stacked.unstack()
# Out:
#       id       marka        model rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III          2014         Diesel
# 1      1         BMW       X1 E84          2012         Diesel
# 2      2        Opel     Zafira A          2004    Benzyna+CNG
# 3      3     Hyundai        i10 I          2008        Benzyna
# 4      4  Volkswagen           CC          2010         Diesel
# ..   ...         ...          ...           ...            ...
# 995  995  Alfa Romeo          159          2009         Diesel
# 996  996       Škoda     Fabia II          2012        Benzyna
# 997  997     Renault        Modus          2004        Benzyna
# 998  998        Audi        A3 8L          2000        Benzyna
# 999  999       Volvo      XC 60 I          2016         Diesel
#
#     pojemnosc_silnika przebieg    cena     wojewodztwo
# 0                1600   160000   75900    Dolnośląskie
# 1                2000   149000   70900  Świętokrzyskie
# ...

# %%
#Przerobienie macierzy na pivot table
pd.pivot_table(df, values='cena', index=['marka','model'],columns='rodzaj_silnika')
# Out:
# rodzaj_silnika                Benzyna  Benzyna+CNG  Benzyna+LPG    Diesel  \
# marka      model
# Alfa Romeo 147            4100.000000          NaN          NaN       NaN
#            156                    NaN          NaN          NaN    6900.0
#            159                    NaN          NaN          NaN   26450.0
#            Spider                 NaN          NaN      10000.0       NaN
# Audi       A1            39999.000000          NaN          NaN       NaN
# ...                               ...          ...          ...       ...
# Škoda      Octavia I     14233.333333          NaN          NaN    6900.0
#            Octavia II    25879.800000          NaN          NaN   25900.0
#            Octavia III  102400.000000          NaN          NaN   49900.0
#            RAPID         55900.000000          NaN          NaN   63800.0
#            Superb III   139900.000000          NaN          NaN  144445.0
#
# rodzaj_silnika          Elektryczny  Hybryda
# ...

# %%
#Utworzenie tablicy jednowymiarowej, ktora zawiera 100 dat przesunietch ms o sekunde
array_date = pd.date_range('1/1/2010', periods=100, freq='S')

#zmiana strefy czasowej na UTC
array_date.tz_localize('UTC')
# Out:
# DatetimeIndex(['2010-01-01 00:00:00+00:00', '2010-01-01 00:00:01+00:00',
#                '2010-01-01 00:00:02+00:00', '2010-01-01 00:00:03+00:00',
#                '2010-01-01 00:00:04+00:00', '2010-01-01 00:00:05+00:00',
#                '2010-01-01 00:00:06+00:00', '2010-01-01 00:00:07+00:00',
#                '2010-01-01 00:00:08+00:00', '2010-01-01 00:00:09+00:00',
#                '2010-01-01 00:00:10+00:00', '2010-01-01 00:00:11+00:00',
#                '2010-01-01 00:00:12+00:00', '2010-01-01 00:00:13+00:00',
#                '2010-01-01 00:00:14+00:00', '2010-01-01 00:00:15+00:00',
#                '2010-01-01 00:00:16+00:00', '2010-01-01 00:00:17+00:00',
#                '2010-01-01 00:00:18+00:00', '2010-01-01 00:00:19+00:00',
#                '2010-01-01 00:00:20+00:00', '2010-01-01 00:00:21+00:00',
#                '2010-01-01 00:00:22+00:00', '2010-01-01 00:00:23+00:00',
#                '2010-01-01 00:00:24+00:00', '2010-01-01 00:00:25+00:00',
# ...

# %%
#usunięcie dnia z daty
array_date.to_period()
# Out:
# PeriodIndex(['2010-01-01 00:00:00', '2010-01-01 00:00:01',
#              '2010-01-01 00:00:02', '2010-01-01 00:00:03',
#              '2010-01-01 00:00:04', '2010-01-01 00:00:05',
#              '2010-01-01 00:00:06', '2010-01-01 00:00:07',
#              '2010-01-01 00:00:08', '2010-01-01 00:00:09',
#              '2010-01-01 00:00:10', '2010-01-01 00:00:11',
#              '2010-01-01 00:00:12', '2010-01-01 00:00:13',
#              '2010-01-01 00:00:14', '2010-01-01 00:00:15',
#              '2010-01-01 00:00:16', '2010-01-01 00:00:17',
#              '2010-01-01 00:00:18', '2010-01-01 00:00:19',
#              '2010-01-01 00:00:20', '2010-01-01 00:00:21',
#              '2010-01-01 00:00:22', '2010-01-01 00:00:23',
#              '2010-01-01 00:00:24', '2010-01-01 00:00:25',
#              '2010-01-01 00:00:26', '2010-01-01 00:00:27',
#              '2010-01-01 00:00:28', '2010-01-01 00:00:29',
#              '2010-01-01 00:00:30', '2010-01-01 00:00:31',
# ...

# %%
#Wygenerowanie 5 dat
array_date = pd.date_range('1/1/2010 00:00', periods=5, freq='D')
print(array_date)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
#Zmiana indeksu na daty
array_date = pd.Series(np.random.randn(len(array_date)), array_date)
print(array_date)
# Out:
# 2010-01-01    0.931282
# 2010-01-02   -1.997039
# 2010-01-03   -0.698362
# 2010-01-04   -0.927104
# 2010-01-05    0.121118
# Freq: D, dtype: float64

# %%
#Utworzenie macierzy z zmiana new1
matrix1 = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6], "new1": ['a1', 'b1', 'c1', 'd1', 'e1', 'f1']})
print(matrix1)
# Out:
#    id new1
# 0   1   a1
# 1   2   b1
# 2   3   c1
# 3   4   d1
# 4   5   e1
# 5   6   f1

# %%
#Dodanie kolumny new2 z wartościmi new1
matrix1["new2"] = matrix1["new1"].astype("category")
print(matrix1)
# Out:
#    id new1 new2
# 0   1   a1   a1
# 1   2   b1   b1
# 2   3   c1   c1
# 3   4   d1   d1
# 4   5   e1   e1
# 5   6   f1   f1

# %%
#Wyświetlenie typów kolumn
df.dtypes
# Out:
# id                     int64
# marka                 object
# model                 object
# rok_produkcji        float64
# rodzaj_silnika        object
# pojemnosc_silnika    float64
# przebieg             float64
# cena                 float64
# wojewodztwo           object
# dtype: object

# %%
#Uzycie funkcji lambda na kolumnach
df.apply(lambda x: x.max())
# Out:
# id                              999
# marka                         Škoda
# model                           up!
# rok_produkcji                  2017
# rodzaj_silnika              Hybryda
# pojemnosc_silnika            191000
# przebieg                     647000
# cena                         616000
# wojewodztwo          Świętokrzyskie
# dtype: object

# %%
#SZukanie duplikatów
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
#Wyświetlanie ilości elementów
print(df.size)

#Wyświetlanie typli zawierającej informacje o kształcie DataFrame
print(df.shape)
# Out:
# 9000
# (1000, 9)
